# %% [markdown]
# ## Chaper2. 퍼셉트론

# %% [markdown]
# ### 퍼셉트론이란?
# * 프랑크 로젠블라트(Frank Rozenblatt)가 1957년에 고안한 알고리즘
# * 다수의 신호를 입력받아 하나의 신호로 출력
# * 모든 신호는 흐른다/안 흐른다(1/0)으로 처리
# ![image.png](attachment:image.png)

# %% [markdown]
# ## References
# * https://towardsdatascience.com/perceptron-the-artificial-neuron-4d8c70d5cc8d
