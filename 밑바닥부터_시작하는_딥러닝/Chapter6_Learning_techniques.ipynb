# %% [markdown]
# ### Chaper6. 학습 관련 기술들

# %% [markdown]
# ### 6.1 매개변수 갱신

# %% [markdown]
# ### 6.2 가중치의 초깃값

# %% [markdown]
# ### 6.3 배치 정규화

# %% [markdown]
# ### 6.4 바른학습을 위해

# %% [markdown]
# ### 6.5 적절한 하이퍼파라미터 값 찾기
